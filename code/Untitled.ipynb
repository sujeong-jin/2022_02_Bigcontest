# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
import pandas as pd
data = pd.read_csv("../../../../../bigcontest/data/preprocessed/data.csv")

# %%
loan_result = pd.read_csv("../../../../../bigcontest/data/loan_result.csv")
log_data = pd.read_csv("../../../../../bigcontest/data/log_data.csv")
user_spec = pd.read_csv("../../../../../bigcontest/data/user_spec.csv")

# %%
user_spec[user_spec["user_id"] == 670502]
# Out:
#         application_id  user_id  birth_year  gender          insert_time  \
# 566158         1746224   670502      1981.0     1.0  2022-06-30 22:41:11
# 597613          341149   670502      1981.0     1.0  2022-06-30 21:32:18
#
#         credit_score  yearly_income  income_type  company_enter_month  \
# 566158         930.0            0.0  OTHERINCOME                  NaN
# 597613         930.0            NaN  OTHERINCOME                  NaN
#
#        employment_type houseown_type  desired_amount purpose  \
# 566158              기타        기타가족소유       6000000.0    사업자금
# 597613              기타        기타가족소유       6000000.0    사업자금
#
#         personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 566158                         0.0                                  0.0
# 597613                         0.0                                  0.0
#
#         existing_loan_cnt  existing_loan_amt
# 566158                1.0          3000000.0
# ...

# %%
data["employment_type"].unique()
# Out:
# array(['정규직', '기타', '계약직', '일용직'], dtype=object)

# %%
data["houseown_type"].unique()
# Out:
# array(['자가', '전월세', '기타가족소유', '배우자'], dtype=object)

# %%
data["purpose"].unique()
# Out:
# array(['생활비', '대환대출', '주택구입', '사업자금', '투자', '기타', '전월세보증금', '자동차구입'],
#       dtype=object)

# %%
data
# Out:
#           is_applied  loan_limit  loan_rate  loan_limit_100million  \
# 0                  1  20000000.0       16.5                  False
# 1                  0  11000000.0       16.5                  False
# 2                  0   3000000.0       20.0                  False
# 3                  0  10000000.0       13.5                  False
# 4                  0  22000000.0       15.9                  False
# ...              ...         ...        ...                    ...
# 10264381           0  30000000.0       13.6                  False
# 10264382           0   9000000.0       14.4                  False
# 10264383           0   3000000.0       11.2                  False
# 10264384           0   4000000.0       15.3                  False
# 10264385           0   9000000.0       15.5                  False
#
#           CompleteIDCertification  EndLoanApply  credit_score  yearly_income  \
# 0                               5            13         540.0     32000000.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot('desired_amount',
        'loan_limit',
        data = data,
        linestyle = 'none',
        marker = 'o')
